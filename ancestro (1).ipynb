# %%
import subprocess
import os

comando_clustalw = ["clustalw", "-INFILE=ancestro.txt"]
subprocess.run(comando_clustalw)

directorio_actual = os.getcwd()

ruta_script_perl = "/home/jorge/Downloads/FastML.v3.11/www/fastml"
os.chdir(ruta_script_perl)

comando = "perl FastML_Wrapper.pl --MSA_File ancestro.aln --outDir /home/jorge/Downloads --seqType aa"
subprocess.run(comando, shell=True)

os.chdir(directorio_actual)
# Out:
#  CLUSTAL 2.1 Multiple Sequence Alignments
#
#
# Sequence format is Pearson
# Sequence 1: NP_003891.1      440 aa
# Sequence 2: PNI26084.1       498 aa
# Sequence 3: AAA93299.1       440 aa
# Sequence 4: AIC55490.1       440 aa
# Sequence 5: NP_001135770.1   356 aa
# Sequence 6: AAV38381.1       441 aa
# Sequence 7: XP_004043182.2   440 aa
# Sequence 8: AKI70215.1       356 aa
# Sequence 9: AKI70218.1       356 aa
# Sequence 10: AKI70217.1       356 aa
# Sequence 11: AKI70216.1       356 aa
# Sequence 12: XP_030867214.2   356 aa
# Sequence 13: XP_033034414.1   440 aa
# Start of Pairwise alignments
# Aligning...
#
# Sequences (1:2) Aligned. Score:  99
# Sequences (1:3) Aligned. Score:  99
# Sequences (1:4) Aligned. Score:  99
# Sequences (1:5) Aligned. Score:  100
# Sequences (1:6) Aligned. Score:  99
# Sequences (1:7) Aligned. Score:  99
# Sequences (1:8) Aligned. Score:  99
# Sequences (1:9) Aligned. Score:  99
# Sequences (1:10) Aligned. Score:  99
# ...
